# %% [markdown]
# <a href="https://colab.research.google.com/github/jioooo20/pengolahan-citra-dan-visi-komputer/blob/main/tugas_kelompok_6_week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#impor
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
ktm = cv.cvtColor(cv.imread('/content/drive/MyDrive/ktm.jpeg'), cv.COLOR_BGR2RGB)
plt.imshow(ktm)
plt.show()

# %% [markdown]
# **Kelompok 6 logo Polinema dan tulisan POLINEM**A

# %%
#kotak polinema
cv.rectangle(ktm, pt1=(500,359), pt2=(1250,500), color=(220,0,190), thickness=10)
#bunder logo
cv.circle(ktm, center=(135,160),radius=100, color=(120,30,190), thickness=10)
plt.imshow(ktm)
plt.show()
#
